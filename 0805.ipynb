# %%
#set 元素不能重複
set1:set = {1,1,3,3,5,8,7,9,10}
set1.add(11)
set1
# Out:
# {1, 3, 5, 7, 8, 9, 10, 11}

# %%
import numpy as np

array1:np.ndarray = np.array(range(1,11))

#陣列運算
array1 +10 * 50
# Out:
# array([501, 502, 503, 504, 505, 506, 507, 508, 509, 510])

# %%
display(np.arrange(1.3,3.5,0.1))
display(np.linspace(1,2,20))

# %%
display(np.random.random())
display(np.random.randn(10,5,3))
display(np.random.randint(1,10,size=(10,5)))

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3,3,50)
display(x)
figure = plt.figure(figsize=(8,4))
axes = figure.add_subplot()
axes.plot(x)
plt.show()
# Out:
# array([-3.        , -2.87755102, -2.75510204, -2.63265306, -2.51020408,
#        -2.3877551 , -2.26530612, -2.14285714, -2.02040816, -1.89795918,
#        -1.7755102 , -1.65306122, -1.53061224, -1.40816327, -1.28571429,
#        -1.16326531, -1.04081633, -0.91836735, -0.79591837, -0.67346939,
#        -0.55102041, -0.42857143, -0.30612245, -0.18367347, -0.06122449,
#         0.06122449,  0.18367347,  0.30612245,  0.42857143,  0.55102041,
#         0.67346939,  0.79591837,  0.91836735,  1.04081633,  1.16326531,
#         1.28571429,  1.40816327,  1.53061224,  1.65306122,  1.7755102 ,
#         1.89795918,  2.02040816,  2.14285714,  2.26530612,  2.3877551 ,
#         2.51020408,  2.63265306,  2.75510204,  2.87755102,  3.        ])

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3,3,50)
x = x * 2 + 10
y = x ** 4
figure = plt.figure(figsize=(8,4))
axes = figure.add_subplot()
axes.plot(x)
axes.plot(y)
plt.show()

# %%
t = np.arange(0.,1.0,0.05)
display(t)
y1 = np.sin(2 * np.pi * t)
y2 = np.cos(2 * np.pi * t)
display(y1)
display(y2)
figure1 = plt.figure(figsize=(8,4))
axes1 = figure1.add_subplot()
axes1.plot(y1)
axes1.plot(y2)
plt.show()
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95])
# array([ 0.00000000e+00,  3.09016994e-01,  5.87785252e-01,  8.09016994e-01,
#         9.51056516e-01,  1.00000000e+00,  9.51056516e-01,  8.09016994e-01,
#         5.87785252e-01,  3.09016994e-01,  1.22464680e-16, -3.09016994e-01,
#        -5.87785252e-01, -8.09016994e-01, -9.51056516e-01, -1.00000000e+00,
#        -9.51056516e-01, -8.09016994e-01, -5.87785252e-01, -3.09016994e-01])
# array([ 1.00000000e+00,  9.51056516e-01,  8.09016994e-01,  5.87785252e-01,
#         3.09016994e-01,  6.12323400e-17, -3.09016994e-01, -5.87785252e-01,
#        -8.09016994e-01, -9.51056516e-01, -1.00000000e+00, -9.51056516e-01,
#        -8.09016994e-01, -5.87785252e-01, -3.09016994e-01, -1.83697020e-16,
#         3.09016994e-01,  5.87785252e-01,  8.09016994e-01,  9.51056516e-01])

# %%
import numpy as np
import pandas as pd

n1 = np.random.randint(200,300,size=(10,))
s1 = pd.Series(data=n1,index=[f'學生{i+1}'for i in range(10)])
display(s1+100)
display(s1.values)
display(s1.index)
# Out:
# 學生1     382
# 學生2     341
# 學生3     365
# 學生4     311
# 學生5     356
# 學生6     392
# 學生7     300
# 學生8     331
# 學生9     305
# 學生10    339
# dtype: int64
# array([282, 241, 265, 211, 256, 292, 200, 231, 205, 239])
# Index(['學生1', '學生2', '學生3', '學生4', '學生5', '學生6', '學生7', '學生8', '學生9', '學生10'], dtype='object')

# %%
import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)
# Out:
# 袁胤儀、蘇佳穎、張怡香、陳昱苓、林子全、蘇佳玲、袁常佩、蔡育維、曾玉娟、陳逸全、林家慧、蔡怡菁、吳紀吉、陳世伯、許嘉玲、陳慧雯、李炳堯、陳凱恩、黃芸伯、林于麟、洪士利、楊政廷、吳文宇、蔡欣仁、許哲湖、陳政啟、林淑明、高雅婷、姚淑惠、高亞貞、柳祥霖、洪百歡、張玟君、陳佳宏、宋姵添、藍昆博、王凱谷、柯佩珊、楊軍友、洪國茂、林翔孜、徐峻政、童瑋玲、陳吟卉、李承淑、徐雅雯、蔡禎靖、吳淑惠、鄭振宇、黃國辰、李怡琇、黃怡羽、陳行沛、陳宗福、陳國羽、林靜容、黃倍成、高筱宸、吳靜茜、李得喜、王寶苓、張佩穎、白昭倩、鄭淑秋、王芝泉、劉子珠、黃佳易、林育星、張淑恩、林士妃、陳俊勇、鬱嘉宏、魏建欣、王俊逸、林敬愛、呂朝幸、吳俊嘉、王家欣、陳志倩、王俊堅、黃建宇、溫欣怡、李惠茹、周淑敏、呂靜怡、連威宇、徐淑貞、謝冰天、張家明、黃宛蓉、戴志文、陳依堅、彭豐以、林雨方、陳柏書、張隆銘、鄭麗鴻、黃蕙珮、陳琪純、陳佳樺

# %%
import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]


names = getNames(100)
# Out:
# <class 'str'>

# %%
import numpy as np
import pandas as pd

n2 = np.random.randint(50,100,size=(50,5))
dataFrame = pd.DataFrame(data=n2,
             index=names[:50],
             columns=["國文","英文","數學","地理","歷史"]
             )
dataFrame
# Out:
#      國文  英文  數學  地理  歷史
# 陳建妮  59  83  87  97  94
# 黎中方  96  57  87  87  65
# 王治娟  56  68  66  66  78
# 謝宗翰  54  64  90  81  65
# 陳惠珍  81  74  99  97  92
# 王子豪  91  56  57  89  94
# 陳品航  96  50  88  57  63
# 阮君易  58  87  77  89  58
# 金俐榮  50  55  90  83  93
# 張力白  98  95  73  59  70
# 賴俊沛  61  61  80  70  77
# 黃承翰  76  73  88  50  66
# 林淑育  93  66  99  79  61
# 蔣宗翰  81  80  50  70  65  346
# 毛炳汝  76  79  73  97  76  401
# 曹秋佐  87  72  72  93  61  385
# 陳政山  51  51  57  74  82  315
# 胡羽嘉  51  91  97  92  52  383
# 林丞夫  81  92  69  73  89  404
# 郭惠珊  94  68  81  56  81  380
# 陳威智  84  56  94  50  56  340
# 查妙亮  68  50  94  69  91  372
# 陳山冰  90  58  60  50  91  349
# 楊惠文  63  94  81  95  99  432
# 林欣樺  93  99  86  66  55  399
# 陳思霖  74  78  93  65  81  391
# 邵穎義  99  93  78  85  66  421
# 賴俊成  98  97  99  50  67  411
# 支佳容  51  77  77  61  51  317
# 蔡碧輝  58  69  57  74  57  315
# 陳金鳳  55  98  66  83  55  357

# %%
import requests
def getNames():
    times = 3
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)    
    return cnames


names = getNames()

# %%
#使用"、"符號,連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 賴哲維
# 蔡雅婷
# 曾怡璇
# 宋怡旭
# 邱俊易
# 陳素亨
# 陳淑辰
# 林思月
# 胡善雪
# 黃宗穎
# 薛秋萍
# 陳冠傑
# 白彥廷
# 宋景凌
# 陳宗君
# 宋湖胤
# 吳婉婷
# 黃維士
# 周欣樺
# 劉伊傑
# 邱思琇
# 劉偉銘
# 楊侑源
# 黃世偉
# 劉芝昌
# 楊世豪
# 陳威合
# 楊幼啟
# 黃文君
# 白淑芬
# 游致遠
# 郭石裕
# 徐哲維
# 陳英傑
# 劉健豪
# 常景翔
# 孫家豪
# 張柏來
# 陳惠志
# 黃建霖
# 張林旭
# 蔡凱妃
# 王家瑋
# 陳雅萍
# 張芝昌
# 夏靜如
# 丁欣潔
# 徐俊彥
# 張星樂
# 翁鈺婷
# 吳欣正
# 彭介邦
# 鄧啟瑩
# 陳雅文
# 宋禹富
# 廖宛君
# 周珊儒
# 鄭雅娥
# 張欣宜
# 李雅劭
# 謝佩瑋
# 黃婉傑
# 蔡梅妤
# 林怡蓁
# 林依婷
# 蔡白麟
# 林祥財
# 楊智珍
# 錢靜怡
# 金宏儒
# 簡欣怡
# 陳瑤政
# 陳志亞
# 李庭合
# 張世仰
# 江穎谷
# 李雅惠
# 朱雅如
# 何建志
# 江伯易
# 陳善泉
# 陳彥平
# 劉舒聿
# 賴士竹
# 葉馨萍
# 陳昱宏
# 呂佳輝
# 黃淑芬
# 蔡佳霖
# 陳宜珊
# 胡宣英
# 謝宗南
# 林俊隆
# 黃文凱
# 陳伊珊
# 李明苓
# 孫玟諭
# 葉文禮
# 郭希胤
# 林坤孝
# 勞泰如
# 林于茂
# 賴威廷
# 張秀娟
# 吳秋松
# 陳偉辛
# 徐淑貞
# 林俐杰
# 李萬火
# 連哲宇
# 黃妍麟
# 江聿添
# 林士銘
# 黃彥廷
# 謝怡君
# 郭香玄
# 胡育儒
# 黃泰蓉
# 黃佩樺
# 陳怡君
# 利玟君
# 黃偉行
# 王永春
# 黃世欣

# %%
with open("names.csv",mode="w",encoding="utf-8",newline="") as file:
    file.write(newLine_name)

# %%
import pandas as pd
current_weather = pd.read_csv("目前天氣.csv")
current_weather
# Out:
#      城市                       啟始時間                       結束時間  最高溫度  最低溫度  \
# 0   臺北市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  35.0  32.0
# 1   新北市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  34.0  31.0
# 2   桃園市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  34.0  31.0
# 3   臺中市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  30.0
# 4   臺南市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  29.0  28.0
# 5   高雄市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  30.0  29.0
# 6   基隆市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  34.0  32.0
# 7   新竹縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  33.0  31.0
# 8   新竹市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  31.0
# 9   苗栗縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  30.0
# 10  彰化縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  31.0  29.0
# 11  南投縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  29.0
# 12  雲林縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  31.0  28.0
# 13  嘉義縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  30.0  28.0
# 14  嘉義市  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  30.0  27.0
# 15  屏東縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  29.0  27.0
# 16  宜蘭縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  35.0  32.0
# 17  花蓮縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  31.0
# 18  臺東縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  30.0
# 19  澎湖縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  31.0  29.0
# 20  金門縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  34.0  30.0
# 21  連江縣  2023-08-05T12:00:00+08:00  2023-08-05T18:00:00+08:00  32.0  29.0
#
#         感覺
# 0   悶熱至易中暑
# 1       悶熱
# 2       悶熱
# 3       悶熱
# 4       悶熱
# 5       悶熱
# 6       悶熱
# 7       悶熱
# 8       悶熱
# 9       悶熱
# 10      悶熱
# 11      悶熱
# 12      悶熱
# 13      悶熱
# 14   舒適至悶熱
# 15      悶熱
# 16  悶熱至易中暑
# 17      悶熱
# 18      悶熱
# 19      悶熱
# 20  悶熱至易中暑
# 21  悶熱至易中暑

# %%
current_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   城市      22 non-null     object
#  1   啟始時間    22 non-null     object
#  2   結束時間    22 non-null     object
#  3   最高溫度    22 non-null     float64
#  4   最低溫度    22 non-null     float64
#  5   感覺      22 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 1.2+ KB

# %%
pd.to_datetime(current_weather['啟始時間'])
# Out:
# 0    2023-08-05 12:00:00+08:00
# 1    2023-08-05 12:00:00+08:00
# 2    2023-08-05 12:00:00+08:00
# 3    2023-08-05 12:00:00+08:00
# 4    2023-08-05 12:00:00+08:00
# 5    2023-08-05 12:00:00+08:00
# 6    2023-08-05 12:00:00+08:00
# 7    2023-08-05 12:00:00+08:00
# 8    2023-08-05 12:00:00+08:00
# 9    2023-08-05 12:00:00+08:00
# 10   2023-08-05 12:00:00+08:00
# 11   2023-08-05 12:00:00+08:00
# 12   2023-08-05 12:00:00+08:00
# 13   2023-08-05 12:00:00+08:00
# 14   2023-08-05 12:00:00+08:00
# 15   2023-08-05 12:00:00+08:00
# 16   2023-08-05 12:00:00+08:00
# 17   2023-08-05 12:00:00+08:00
# 18   2023-08-05 12:00:00+08:00
# 19   2023-08-05 12:00:00+08:00
# 20   2023-08-05 12:00:00+08:00
# 21   2023-08-05 12:00:00+08:00
# Name: 啟始時間, dtype: datetime64[ns, UTC+08:00]
